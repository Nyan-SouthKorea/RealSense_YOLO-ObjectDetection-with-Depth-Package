# %% [markdown]
# ### yolov7 공식 레포지토리를 가져와서 scratch로 구현 테스트

# %%
# 모델 로드
from  hubconf import custom
import numpy as np
import cv2

model = custom(path_or_model='weights/240501_best.pt')  # custom example
# model = create(name='yolov7', pretrained=True, channels=3, classes=80, autoshape=True)  # pretrained example
# Out:
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   5                -2  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   6                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   7                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   8                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   9                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  10  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  11                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  12                -1  1         0  models.common.MP                        []
#  13                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  14                -3  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  16          [-1, -3]  1         0  models.common.Concat                    [1]
#  17                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  18                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  20                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  22                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  23  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  24                -1  1    263168  models.common.Conv                      [512, 512, 1, 1]
#  25                -1  1         0  models.common.MP                        []
#  26                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  27                -3  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  28                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  29          [-1, -3]  1         0  models.common.Concat                    [1]
#  30                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  31                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  32                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  33                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  34                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  35                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  36  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  37                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  38                -1  1         0  models.common.MP                        []
#  39                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  40                -3  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  41                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  42          [-1, -3]  1         0  models.common.Concat                    [1]
#  43                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  44                -2  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  45                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  46                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  47                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  48                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  49  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  50                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  51                -1  1   7609344  models.common.SPPCSPC                   [1024, 512, 1]
#  52                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  53                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  54                37  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  55          [-1, -2]  1         0  models.common.Concat                    [1]
#  56                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  57                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  58                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  59                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  60                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  61                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  62[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  63                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  64                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  65                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  66                24  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  67          [-1, -2]  1         0  models.common.Concat                    [1]
#  68                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  69                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  70                -1  1     73856  models.common.Conv                      [128, 64, 3, 1]
#  71                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  72                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  73                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  74[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  75                -1  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  76                -1  1         0  models.common.MP                        []
#  77                -1  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  78                -3  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  79                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  80      [-1, -3, 63]  1         0  models.common.Concat                    [1]
#  81                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  82                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  83                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  84                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  85                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  86                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  87[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  88                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  89                -1  1         0  models.common.MP                        []
#  90                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  91                -3  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  92                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  93      [-1, -3, 51]  1         0  models.common.Concat                    [1]
#  94                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  95                -2  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  96                -1  1   1180160  models.common.Conv                      [512, 256, 3, 1]
#  97                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  98                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  99                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 100[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
# 101                -1  1   1049600  models.common.Conv                      [2048, 512, 1, 1]
# 102                75  1    328704  models.common.RepConv                   [128, 256, 3, 1]
# 103                88  1   1312768  models.common.RepConv                   [256, 512, 3, 1]
# 104               101  1   5246976  models.common.RepConv                   [512, 1024, 3, 1]
# 105   [102, 103, 104]  1    129240  models.yolo.Detect                      [19, [[12, 16, 19, 36, 40, 28], [36, 75, 76, 55, 72, 146], [142, 110, 192, 243, 459, 401]], [256, 512, 1024]]
# Model Summary: 407 layers, 37291640 parameters, 37291640 gradients, 105.4 GFLOPS
#
# YOLOR  e762db2 torch 2.2.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12287.5MB)
# Adding autoShape...

# %%
# 인퍼런스
# Verify inference
img = cv2.imread('test_image.png')
results = model(img).pandas().xyxy[0]  # batched inference
print(results)
# Out:
#          xmin        ymin        xmax        ymax  confidence  class    name
# 0  598.207397   66.344719  755.817139  406.846863    0.822754      4  person
# 1  102.165428  114.544327  340.649994  420.449219    0.799316      4  person
# 2  417.828491   71.963081  746.354675  417.492188    0.791992      4  person
# 3    0.036963  103.011909   85.014648  415.717957    0.722656      4  person
# 4  392.693726   77.655365  503.878113  284.130066    0.676270      4  person
# 5  250.904099   89.113861  464.253876  419.857819    0.675293      4  person
# 6    1.108887  243.766586  169.142181  420.449219    0.661621      4  person
# 7   40.954880   73.441597  145.929489  251.159164    0.657227      4  person
# 8  295.703125    1.290040  413.392944  109.073822    0.624512      4  person
# 9  171.507812    0.000000  293.041779  134.208588    0.287354      4  person

# %%
# 후처리
dic_list = []
for idx, row in results.iterrows():
    bbox = [int(row['xmin']), int(row['ymin']), int(row['xmax']), int(row['ymax'])]
    conf = row['confidence']
    class_no = row['class']
    name = row['name']
    dic_list.append({'bbox':bbox, 'conf':conf, 'class_no':class_no, 'name':name})
print(dic_list[0])
# Out:
# {'bbox': [598.2073974609375, 66.34471893310547, 755.817138671875, 406.84686279296875], 'conf': 0.82275390625, 'class_no': 4, 'name': 'person'}

# %%
from hubconf import custom
import time
import cv2

# 모듈 제작 테스트
class custom_yolov7_run:
    '''
    240524
    YOLOv7 공식 레포지토리 참고하여 numpy 이미지를 입력하면 dic으로 이루어진 list형태로 인퍼런스 결과가 도출되도록 만든 모듈
    '''
    def __init__(self, model_path):
        '''
        model_path: YOLOv7 wieght파일 경로
        '''
        self.model = custom(path_or_model = model_path)
        
    def detect(self, bgr_img):
        '''
        이미지를 입력하면 dic으로 이루어진 list를 반환
        img: cv2로 로드한 bgr 이미지를 입력(함수 안에서 rgb로 변환함)
        '''
        # 이미지 bgr -> rgb
        self.bgr_img = bgr_img # 나중에 그릴 때 사용
        self.img = cv2.cvtColor(self.bgr_img, cv2.COLOR_BGR2RGB)
        # 인퍼런스
        start = time.time()
        results = self.model(self.img).pandas().xyxy[0]
        spent_time = round(time.time() - start, 3)
        # 후처리
        self.dic_list = []
        for idx, row in results.iterrows():
            bbox = [int(row['xmin']), int(row['ymin']), int(row['xmax']), int(row['ymax'])]
            conf = round(row['confidence'], 3)
            class_no = row['class']
            name = row['name']
            self.dic_list.append({'bbox':bbox, 'conf':conf, 'class_no':class_no, 'name':name, 'inf_time':spent_time})
        return self.dic_list
    
    def draw(self):
        '''
        self.img에 self.dic_list로 그림그려진 이미지를 반환
        '''
        for dic in self.dic_list:
            cv2.rectangle(self.bgr_img, (dic['bbox'][0], dic['bbox'][1]), (dic['bbox'][2], dic['bbox'][3]), (0,0,255), 2)
            text = f'{dic["name"]}:{dic["conf"]}'
            cv2.putText(self.bgr_img, text, (dic['bbox'][0], dic['bbox'][1]+25), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
        return self.bgr_img

# %%
# 240514 Real Sense 카메라 사용 모듈
import pyrealsense2 as rs
import numpy as np
import cv2

class real_sense:
    def __init__(self):
        '''
        Real Sense 카메라 연결하여 파이썬으로 RGB 이미지와 Depth Map을 불러오는 Class.
        공식 문서를 참고하여 사용하기 쉽게 Class의 형태로 제작함
        '''
        # Configure depth and color streams
        self.pipeline = rs.pipeline()
        config = rs.config()

        # Get device product line for setting a supporting resolution
        pipeline_wrapper = rs.pipeline_wrapper(self.pipeline)
        pipeline_profile = config.resolve(pipeline_wrapper)
        device = pipeline_profile.get_device()
        device_product_line = str(device.get_info(rs.camera_info.product_line))

        found_rgb = False
        for s in device.sensors:
            if s.get_info(rs.camera_info.name) == 'RGB Camera':
                found_rgb = True
                break
        if not found_rgb:
            print("The demo requires Depth camera with Color sensor")
            exit(0)

        config.enable_stream(rs.stream.depth, 640, 480, rs.format.z16, 30)
        config.enable_stream(rs.stream.color, 640, 480, rs.format.bgr8, 30)

        # Start streaming
        self.pipeline.start(config)
        print('Real Sense 카메라 수신 설정 완료')

    def get_cam(self):
        '''
        RealSense 카메라에서 frame들을 가져옴.
        이 frame들에서 RGB이미지, Depth맵 등 다양한 이미지가 추출됨
        frame이 return되지는 않고, 내부 변수로 활용됨
        '''
        self.frames = self.pipeline.wait_for_frames()
    
    def get_color_img(self):
        '''
        get_cam 실행 이후에 실행되어야 에러가 발생하지 않음
        self.frames라는 변수가 존재해야 실행 가능한 로직이기 때문임
        '''
        color_frame = self.frames.get_color_frame()
        if color_frame:
            self.color_image = np.asanyarray(color_frame.get_data())
            return self.color_image
        else:
            print('get_color_img 에러 발생!')
        
    def get_depth_img(self):
        '''
        get_cam 실행 이후에 실행되어야 에러가 발생하지 않음
        self.frames라는 변수가 존재해야 실행 가능한 로직이기 때문임
        '''
        depth_frame = self.frames.get_depth_frame()
        if depth_frame:
            self.depth_image = np.asanyarray(depth_frame.get_data())
            return self.depth_image
        else:
            print('get_depth_img 에러 발생!')

    def get_depth_color_map(self):
        '''
        self.depth_image로부터 color_map을 만들어서 반환함
        반드시 get_depth_img 함수가 실행되어야 에러가 발생하지 않음
        self.depth_image가 존재해야 실행 가능한 로직이기 때문임
        '''
        self.depth_colormap = cv2.applyColorMap(cv2.convertScaleAbs(self.depth_image, alpha=0.03), cv2.COLORMAP_JET)
        return self.depth_colormap
    
    def concat_all(self):
        '''
        위에서 만든 color_img, depth_map, depth_color_map 3개를 가로 Concat하여 반환
        위 3개 이미지가 모두 존재해야 에러가 발생하지 않음
        위 3개 함수를 선언하지 않고 코드를 실행하면 이전 frame의 이미지가 concat될 것임(주의 필요)
        '''
        # 깊이 이미지의 최대값을 확인하고, 8비트 형식으로 스케일 조정
        scaled_depth_image = cv2.convertScaleAbs(self.depth_image, alpha=(255.0/np.max(self.depth_image)))
        depth_3d = cv2.cvtColor(scaled_depth_image, cv2.COLOR_GRAY2BGR) # 1차원인 depth 이미지를 3차원으로 변경함
        concatenated_image = cv2.hconcat([self.color_image, depth_3d, self.depth_colormap])
        return concatenated_image

# %%
# 리얼센스 카메라 스트리밍 테스트
RealSense = real_sense()
while True:
    RealSense.get_cam() # 카메라 수신
    color_img = RealSense.get_color_img()
    depth_img = RealSense.get_depth_img()
    depth_color_map = RealSense.get_depth_color_map()
    cv2.imshow('Real Sense Streaming[color_img, depth_img, depth_color_map]', RealSense.concat_all())
    cv2.imshow('depth map', RealSense.depth_image)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
        break
# Out:
# Real Sense 카메라 수신 설정 완료

# %%
# Real Sense로 영상 받아서 YOLOv7 인퍼런스 테스트
RealSense = real_sense()
model = custom_yolov7_run(model_path = 'weights/240501_best.pt')
while True:
    RealSense.get_cam() # 카메라 수신
    color_img = RealSense.get_color_img()
    # depth_img = RealSense.get_depth_img()
    # depth_color_map = RealSense.get_depth_color_map()
    result = model.detect(bgr_img = color_img)
    print(result)
    cv2.imshow('YOLOv7 test', model.draw())
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
        break
# Out:
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   5                -2  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   6                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   7                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   8                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   9                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  10  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  11                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  12                -1  1         0  models.common.MP                        []
#  13                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  14                -3  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  16          [-1, -3]  1         0  models.common.Concat                    [1]
#  17                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  18                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  20                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  22                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  23  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  24                -1  1    263168  models.common.Conv                      [512, 512, 1, 1]
#  25                -1  1         0  models.common.MP                        []
#  26                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  27                -3  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  28                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  29          [-1, -3]  1         0  models.common.Concat                    [1]
#  30                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  31                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  32                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  33                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  34                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  35                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  36  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  37                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  38                -1  1         0  models.common.MP                        []
#  39                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  40                -3  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  41                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  42          [-1, -3]  1         0  models.common.Concat                    [1]
#  43                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  44                -2  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  45                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  46                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  47                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  48                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  49  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  50                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  51                -1  1   7609344  models.common.SPPCSPC                   [1024, 512, 1]
#  52                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  53                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  54                37  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  55          [-1, -2]  1         0  models.common.Concat                    [1]
#  56                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  57                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  58                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  59                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  60                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  61                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  62[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  63                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  64                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  65                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  66                24  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  67          [-1, -2]  1         0  models.common.Concat                    [1]
#  68                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  69                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  70                -1  1     73856  models.common.Conv                      [128, 64, 3, 1]
#  71                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  72                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  73                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  74[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  75                -1  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  76                -1  1         0  models.common.MP                        []
#  77                -1  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  78                -3  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  79                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  80      [-1, -3, 63]  1         0  models.common.Concat                    [1]
#  81                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  82                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  83                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  84                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  85                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  86                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  87[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  88                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  89                -1  1         0  models.common.MP                        []
#  90                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  91                -3  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  92                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  93      [-1, -3, 51]  1         0  models.common.Concat                    [1]
#  94                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  95                -2  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  96                -1  1   1180160  models.common.Conv                      [512, 256, 3, 1]
#  97                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  98                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  99                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 100[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
# 101                -1  1   1049600  models.common.Conv                      [2048, 512, 1, 1]
# 102                75  1    328704  models.common.RepConv                   [128, 256, 3, 1]
# 103                88  1   1312768  models.common.RepConv                   [256, 512, 3, 1]
# 104               101  1   5246976  models.common.RepConv                   [512, 1024, 3, 1]
# Real Sense 카메라 수신 설정 완료
# 105   [102, 103, 104]  1    129240  models.yolo.Detect                      [19, [[12, 16, 19, 36, 40, 28], [36, 75, 76, 55, 72, 146], [142, 110, 192, 243, 459, 401]], [256, 512, 1024]]
# Model Summary: 407 layers, 37291640 parameters, 37291640 gradients, 105.4 GFLOPS
#
# YOLOR  e762db2 torch 2.2.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12287.5MB)
# Adding autoShape...
# [{'bbox': [14, 67, 477, 479], 'conf': 0.763, 'class_no': 4, 'name': 'person', 'inf_time': 0.172}, {'bbox': [464, 164, 640, 339], 'conf': 0.754, 'class_no': 12, 'name': 'TV', 'inf_time': 0.172}, {'bbox': [0, 163, 112, 289], 'conf': 0.463, 'class_no': 7, 'name': 'chair', 'inf_time': 0.172}]
# [{'bbox': [13, 70, 476, 480], 'conf': 0.756, 'class_no': 4, 'name': 'person', 'inf_time': 0.018}, {'bbox': [464, 163, 640, 340], 'conf': 0.756, 'class_no': 12, 'name': 'TV', 'inf_time': 0.018}, {'bbox': [0, 164, 114, 289], 'conf': 0.523, 'class_no': 7, 'name': 'chair', 'inf_time': 0.018}]
# [{'bbox': [464, 164, 640, 339], 'conf': 0.757, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [7, 71, 475, 479], 'conf': 0.753, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 163, 114, 290], 'conf': 0.441, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [2, 71, 475, 479], 'conf': 0.773, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}, {'bbox': [464, 164, 640, 339], 'conf': 0.753, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}, {'bbox': [0, 165, 113, 288], 'conf': 0.497, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}, {'bbox': [324, 293, 371, 321], 'conf': 0.268, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}]
# [{'bbox': [465, 164, 640, 340], 'conf': 0.757, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [1, 71, 476, 476], 'conf': 0.736, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 164, 113, 290], 'conf': 0.363, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 164, 640, 339], 'conf': 0.759, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}, {'bbox': [2, 73, 475, 472], 'conf': 0.733, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}, {'bbox': [0, 165, 112, 288], 'conf': 0.413, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}, {'bbox': [324, 293, 371, 321], 'conf': 0.252, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}]
# [{'bbox': [466, 164, 640, 339], 'conf': 0.731, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [1, 71, 475, 476], 'conf': 0.724, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 165, 113, 289], 'conf': 0.391, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 371, 321], 'conf': 0.262, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 164, 640, 339], 'conf': 0.748, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}, {'bbox': [1, 71, 475, 477], 'conf': 0.731, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [0, 165, 113, 287], 'conf': 0.529, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [324, 293, 371, 321], 'conf': 0.272, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}]
# [{'bbox': [464, 163, 640, 339], 'conf': 0.75, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [2, 74, 475, 473], 'conf': 0.724, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 165, 113, 287], 'conf': 0.491, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 371, 321], 'conf': 0.275, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 163, 640, 338], 'conf': 0.767, 'class_no': 12, 'name': 'TV', 'inf_time': 0.017}, {'bbox': [2, 74, 474, 473], 'conf': 0.732, 'class_no': 4, 'name': 'person', 'inf_time': 0.017}, {'bbox': [0, 165, 113, 288], 'conf': 0.435, 'class_no': 7, 'name': 'chair', 'inf_time': 0.017}]
# [{'bbox': [464, 164, 640, 338], 'conf': 0.76, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}, {'bbox': [1, 72, 475, 475], 'conf': 0.726, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [0, 165, 112, 289], 'conf': 0.472, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [324, 293, 371, 321], 'conf': 0.282, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}]
# [{'bbox': [464, 164, 640, 339], 'conf': 0.766, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [2, 72, 475, 479], 'conf': 0.749, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 165, 113, 288], 'conf': 0.441, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 371, 321], 'conf': 0.255, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [465, 163, 640, 339], 'conf': 0.759, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [2, 72, 475, 477], 'conf': 0.743, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 164, 113, 288], 'conf': 0.386, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 371, 321], 'conf': 0.282, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [465, 164, 640, 339], 'conf': 0.769, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [2, 72, 475, 479], 'conf': 0.749, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 164, 113, 288], 'conf': 0.454, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 371, 321], 'conf': 0.262, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 163, 640, 339], 'conf': 0.755, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [3, 72, 475, 477], 'conf': 0.746, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 165, 113, 288], 'conf': 0.47, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [466, 164, 640, 339], 'conf': 0.742, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [3, 72, 475, 477], 'conf': 0.742, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 166, 113, 288], 'conf': 0.489, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 163, 640, 338], 'conf': 0.764, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [3, 72, 475, 478], 'conf': 0.739, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 165, 113, 289], 'conf': 0.353, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 163, 640, 339], 'conf': 0.766, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [4, 72, 475, 479], 'conf': 0.75, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 164, 113, 288], 'conf': 0.505, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 370, 321], 'conf': 0.251, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [5, 72, 475, 479], 'conf': 0.748, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 163, 640, 339], 'conf': 0.717, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 164, 114, 289], 'conf': 0.439, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 371, 321], 'conf': 0.258, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 164, 640, 339], 'conf': 0.774, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [6, 72, 475, 478], 'conf': 0.732, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 165, 114, 294], 'conf': 0.491, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [7, 72, 475, 479], 'conf': 0.751, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 163, 640, 339], 'conf': 0.749, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 164, 114, 289], 'conf': 0.525, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 164, 640, 338], 'conf': 0.769, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [7, 72, 475, 479], 'conf': 0.754, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 164, 114, 289], 'conf': 0.449, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 371, 321], 'conf': 0.25, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 163, 640, 338], 'conf': 0.76, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [7, 72, 476, 479], 'conf': 0.751, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 164, 114, 289], 'conf': 0.486, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 371, 321], 'conf': 0.267, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [465, 164, 640, 339], 'conf': 0.758, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [7, 71, 476, 479], 'conf': 0.745, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 165, 114, 289], 'conf': 0.431, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 371, 321], 'conf': 0.259, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 164, 640, 339], 'conf': 0.761, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [7, 70, 475, 479], 'conf': 0.739, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 164, 114, 290], 'conf': 0.485, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 163, 640, 339], 'conf': 0.762, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [6, 70, 475, 479], 'conf': 0.748, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 165, 113, 288], 'conf': 0.453, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 370, 321], 'conf': 0.271, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 163, 640, 339], 'conf': 0.77, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [7, 70, 475, 479], 'conf': 0.745, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 165, 113, 291], 'conf': 0.404, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 164, 640, 338], 'conf': 0.77, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}, {'bbox': [7, 69, 475, 479], 'conf': 0.749, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}, {'bbox': [0, 164, 113, 288], 'conf': 0.403, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}, {'bbox': [324, 293, 370, 321], 'conf': 0.266, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}]
# [{'bbox': [464, 164, 640, 338], 'conf': 0.769, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [6, 68, 476, 477], 'conf': 0.746, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 164, 113, 291], 'conf': 0.443, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 370, 321], 'conf': 0.304, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 163, 640, 339], 'conf': 0.761, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [6, 67, 475, 479], 'conf': 0.758, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 164, 111, 289], 'conf': 0.433, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 370, 321], 'conf': 0.253, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 163, 640, 339], 'conf': 0.763, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}, {'bbox': [5, 67, 476, 478], 'conf': 0.759, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}, {'bbox': [0, 163, 111, 289], 'conf': 0.43, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}, {'bbox': [324, 293, 370, 321], 'conf': 0.292, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}]
# [{'bbox': [4, 67, 476, 478], 'conf': 0.764, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 163, 640, 338], 'conf': 0.76, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 165, 110, 288], 'conf': 0.431, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 370, 321], 'conf': 0.266, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 163, 640, 338], 'conf': 0.776, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}, {'bbox': [3, 66, 475, 478], 'conf': 0.773, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}, {'bbox': [0, 164, 109, 290], 'conf': 0.456, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}, {'bbox': [324, 293, 370, 321], 'conf': 0.288, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}]
# [{'bbox': [464, 163, 640, 338], 'conf': 0.777, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [3, 67, 475, 474], 'conf': 0.757, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 164, 108, 288], 'conf': 0.438, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 164, 640, 339], 'conf': 0.773, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}, {'bbox': [1, 67, 475, 476], 'conf': 0.77, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [0, 165, 107, 288], 'conf': 0.447, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}]
# [{'bbox': [464, 163, 640, 339], 'conf': 0.772, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 66, 476, 476], 'conf': 0.771, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 166, 105, 288], 'conf': 0.42, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 65, 476, 473], 'conf': 0.78, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 163, 640, 338], 'conf': 0.758, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 165, 103, 288], 'conf': 0.363, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [324, 293, 370, 321], 'conf': 0.294, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 64, 476, 472], 'conf': 0.773, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 163, 640, 339], 'conf': 0.745, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 165, 102, 288], 'conf': 0.373, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 64, 476, 471], 'conf': 0.767, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}, {'bbox': [464, 164, 640, 339], 'conf': 0.759, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}, {'bbox': [0, 165, 100, 287], 'conf': 0.396, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}]
# [{'bbox': [464, 163, 640, 338], 'conf': 0.777, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}, {'bbox': [0, 63, 476, 473], 'conf': 0.764, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [0, 165, 99, 286], 'conf': 0.347, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}]
# [{'bbox': [464, 164, 640, 338], 'conf': 0.782, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 63, 476, 470], 'conf': 0.768, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 165, 97, 286], 'conf': 0.331, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [466, 163, 640, 339], 'conf': 0.77, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 63, 477, 470], 'conf': 0.766, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [0, 165, 96, 286], 'conf': 0.316, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 64, 477, 471], 'conf': 0.764, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 339], 'conf': 0.747, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 168, 94, 286], 'conf': 0.3, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [464, 163, 640, 338], 'conf': 0.767, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 64, 477, 471], 'conf': 0.767, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [324, 293, 370, 321], 'conf': 0.256, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 64, 478, 470], 'conf': 0.791, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 338], 'conf': 0.764, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}]
# [{'bbox': [0, 65, 478, 472], 'conf': 0.774, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 163, 640, 339], 'conf': 0.733, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}]
# [{'bbox': [0, 66, 478, 474], 'conf': 0.785, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 339], 'conf': 0.711, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}]
# [{'bbox': [0, 66, 478, 470], 'conf': 0.765, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 163, 640, 339], 'conf': 0.744, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 165, 104, 280], 'conf': 0.257, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 66, 478, 471], 'conf': 0.778, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 163, 640, 339], 'conf': 0.75, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}]
# [{'bbox': [0, 69, 481, 474], 'conf': 0.818, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 339], 'conf': 0.741, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [261, 405, 639, 480], 'conf': 0.45, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}]
# [{'bbox': [0, 69, 482, 474], 'conf': 0.837, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 165, 640, 340], 'conf': 0.747, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [255, 397, 639, 479], 'conf': 0.479, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}]
# [{'bbox': [0, 70, 481, 476], 'conf': 0.867, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}, {'bbox': [465, 164, 640, 340], 'conf': 0.764, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}, {'bbox': [255, 387, 639, 480], 'conf': 0.447, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}]
# [{'bbox': [0, 70, 474, 476], 'conf': 0.899, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 163, 640, 341], 'conf': 0.719, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [258, 385, 638, 479], 'conf': 0.425, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}]
# [{'bbox': [0, 71, 461, 467], 'conf': 0.898, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.736, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [264, 381, 640, 479], 'conf': 0.394, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}]
# [{'bbox': [1, 72, 444, 474], 'conf': 0.895, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 163, 640, 341], 'conf': 0.761, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [255, 381, 639, 479], 'conf': 0.358, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}]
# [{'bbox': [1, 74, 433, 478], 'conf': 0.864, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}, {'bbox': [464, 163, 640, 340], 'conf': 0.817, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}]
# [{'bbox': [1, 79, 416, 474], 'conf': 0.859, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}, {'bbox': [464, 164, 640, 339], 'conf': 0.8, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}]
# [{'bbox': [464, 163, 640, 340], 'conf': 0.799, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}, {'bbox': [1, 82, 407, 478], 'conf': 0.767, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}]
# [{'bbox': [464, 164, 640, 339], 'conf': 0.799, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 85, 407, 480], 'conf': 0.655, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}]
# [{'bbox': [464, 164, 640, 339], 'conf': 0.81, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}, {'bbox': [0, 88, 474, 478], 'conf': 0.735, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}]
# [{'bbox': [465, 164, 640, 340], 'conf': 0.797, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}, {'bbox': [0, 89, 478, 478], 'conf': 0.796, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}]
# [{'bbox': [1, 94, 468, 478], 'conf': 0.838, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 339], 'conf': 0.813, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}]
# [{'bbox': [464, 164, 640, 339], 'conf': 0.817, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}, {'bbox': [0, 98, 437, 477], 'conf': 0.756, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}]
# [{'bbox': [1, 101, 425, 478], 'conf': 0.849, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.81, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}]
# [{'bbox': [1, 103, 413, 479], 'conf': 0.876, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 340], 'conf': 0.819, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}]
# [{'bbox': [1, 105, 400, 479], 'conf': 0.899, 'class_no': 4, 'name': 'person', 'inf_time': 0.017}, {'bbox': [464, 164, 640, 340], 'conf': 0.83, 'class_no': 12, 'name': 'TV', 'inf_time': 0.017}]
# [{'bbox': [1, 109, 391, 479], 'conf': 0.903, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.813, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}]
# [{'bbox': [1, 111, 382, 479], 'conf': 0.891, 'class_no': 4, 'name': 'person', 'inf_time': 0.017}, {'bbox': [464, 164, 640, 340], 'conf': 0.81, 'class_no': 12, 'name': 'TV', 'inf_time': 0.017}]
# [{'bbox': [1, 115, 377, 479], 'conf': 0.877, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.814, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}]
# [{'bbox': [0, 118, 369, 479], 'conf': 0.895, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 340], 'conf': 0.807, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 197, 104, 288], 'conf': 0.3, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 121, 363, 479], 'conf': 0.9, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.82, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 199, 104, 296], 'conf': 0.29, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 125, 361, 479], 'conf': 0.899, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}, {'bbox': [465, 164, 640, 340], 'conf': 0.824, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}, {'bbox': [0, 202, 104, 298], 'conf': 0.363, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}]
# [{'bbox': [0, 128, 356, 480], 'conf': 0.901, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.813, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 204, 104, 299], 'conf': 0.364, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [1, 132, 350, 480], 'conf': 0.902, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 340], 'conf': 0.824, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 205, 105, 298], 'conf': 0.428, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [1, 134, 346, 479], 'conf': 0.91, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 340], 'conf': 0.817, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 206, 106, 297], 'conf': 0.437, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [1, 136, 343, 479], 'conf': 0.914, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 340], 'conf': 0.831, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 209, 106, 297], 'conf': 0.469, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 139, 332, 479], 'conf': 0.925, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [465, 164, 640, 340], 'conf': 0.835, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}, {'bbox': [0, 209, 105, 298], 'conf': 0.406, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}]
# [{'bbox': [1, 141, 327, 478], 'conf': 0.922, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}, {'bbox': [464, 164, 640, 341], 'conf': 0.826, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}, {'bbox': [0, 210, 106, 297], 'conf': 0.403, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}]
# [{'bbox': [1, 142, 308, 478], 'conf': 0.908, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}, {'bbox': [465, 164, 640, 340], 'conf': 0.815, 'class_no': 12, 'name': 'TV', 'inf_time': 0.014}, {'bbox': [0, 211, 106, 298], 'conf': 0.38, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}]
# [{'bbox': [1, 144, 309, 478], 'conf': 0.923, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 341], 'conf': 0.825, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 212, 106, 301], 'conf': 0.38, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 144, 290, 478], 'conf': 0.911, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 341], 'conf': 0.815, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 213, 106, 301], 'conf': 0.407, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 146, 286, 478], 'conf': 0.904, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.817, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 214, 106, 302], 'conf': 0.392, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [303, 319, 386, 418], 'conf': 0.262, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 148, 276, 478], 'conf': 0.926, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.832, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 216, 105, 303], 'conf': 0.394, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [302, 319, 386, 418], 'conf': 0.254, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 148, 276, 478], 'conf': 0.921, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 339], 'conf': 0.827, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 217, 105, 302], 'conf': 0.406, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [305, 319, 386, 418], 'conf': 0.253, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 149, 275, 478], 'conf': 0.924, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 339], 'conf': 0.825, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 217, 105, 303], 'conf': 0.49, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [307, 319, 385, 416], 'conf': 0.299, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 150, 275, 479], 'conf': 0.925, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 340], 'conf': 0.834, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 218, 104, 304], 'conf': 0.382, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [307, 319, 386, 417], 'conf': 0.293, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 151, 274, 479], 'conf': 0.922, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 340], 'conf': 0.827, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 219, 104, 303], 'conf': 0.323, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 151, 273, 479], 'conf': 0.924, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.823, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 220, 104, 303], 'conf': 0.327, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 151, 271, 479], 'conf': 0.927, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.838, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 222, 104, 298], 'conf': 0.427, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [305, 319, 386, 417], 'conf': 0.281, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 151, 269, 479], 'conf': 0.926, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 341], 'conf': 0.823, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 222, 103, 292], 'conf': 0.418, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 151, 266, 479], 'conf': 0.925, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.833, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 224, 104, 292], 'conf': 0.472, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [300, 319, 386, 419], 'conf': 0.389, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 150, 265, 479], 'conf': 0.927, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 340], 'conf': 0.833, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 225, 105, 292], 'conf': 0.487, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 149, 263, 479], 'conf': 0.924, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.836, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 226, 104, 293], 'conf': 0.479, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [307, 319, 385, 416], 'conf': 0.253, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 149, 261, 479], 'conf': 0.921, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 340], 'conf': 0.835, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 227, 103, 291], 'conf': 0.446, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [305, 319, 386, 417], 'conf': 0.292, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 148, 260, 478], 'conf': 0.92, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [465, 163, 640, 340], 'conf': 0.817, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}, {'bbox': [0, 228, 101, 292], 'conf': 0.456, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [303, 319, 386, 418], 'conf': 0.312, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}]
# [{'bbox': [0, 147, 259, 478], 'conf': 0.92, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.827, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 229, 101, 291], 'conf': 0.418, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [305, 319, 386, 417], 'conf': 0.261, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 146, 258, 478], 'conf': 0.921, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [465, 164, 640, 339], 'conf': 0.814, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}, {'bbox': [0, 230, 100, 291], 'conf': 0.436, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [305, 319, 386, 418], 'conf': 0.255, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}]
# [{'bbox': [0, 145, 257, 479], 'conf': 0.922, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.825, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 231, 98, 289], 'conf': 0.398, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 144, 255, 479], 'conf': 0.921, 'class_no': 4, 'name': 'person', 'inf_time': 0.017}, {'bbox': [465, 164, 640, 340], 'conf': 0.825, 'class_no': 12, 'name': 'TV', 'inf_time': 0.017}, {'bbox': [0, 231, 94, 287], 'conf': 0.398, 'class_no': 7, 'name': 'chair', 'inf_time': 0.017}]
# [{'bbox': [0, 143, 254, 479], 'conf': 0.92, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 341], 'conf': 0.824, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [0, 232, 92, 284], 'conf': 0.411, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 142, 254, 479], 'conf': 0.921, 'class_no': 4, 'name': 'person', 'inf_time': 0.018}, {'bbox': [464, 164, 640, 340], 'conf': 0.818, 'class_no': 12, 'name': 'TV', 'inf_time': 0.018}, {'bbox': [0, 233, 90, 284], 'conf': 0.389, 'class_no': 7, 'name': 'chair', 'inf_time': 0.018}]
# [{'bbox': [0, 141, 253, 479], 'conf': 0.921, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 163, 640, 341], 'conf': 0.817, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [1, 233, 88, 282], 'conf': 0.465, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [299, 319, 386, 419], 'conf': 0.4, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 140, 252, 479], 'conf': 0.921, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.821, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [3, 234, 86, 281], 'conf': 0.481, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [305, 319, 386, 418], 'conf': 0.329, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 138, 251, 479], 'conf': 0.921, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 341], 'conf': 0.826, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [4, 235, 82, 281], 'conf': 0.444, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [306, 319, 386, 417], 'conf': 0.274, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 137, 250, 479], 'conf': 0.921, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 341], 'conf': 0.823, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [6, 236, 78, 281], 'conf': 0.483, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [302, 319, 386, 418], 'conf': 0.322, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 135, 249, 479], 'conf': 0.922, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.809, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [8, 236, 75, 281], 'conf': 0.451, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [301, 319, 386, 420], 'conf': 0.406, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 134, 247, 479], 'conf': 0.919, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 339], 'conf': 0.812, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [9, 236, 71, 282], 'conf': 0.395, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [305, 319, 386, 418], 'conf': 0.253, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 132, 243, 479], 'conf': 0.914, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [464, 164, 640, 340], 'conf': 0.82, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}, {'bbox': [10, 236, 66, 281], 'conf': 0.343, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [305, 319, 386, 418], 'conf': 0.3, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}]
# [{'bbox': [0, 129, 239, 479], 'conf': 0.911, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [465, 164, 640, 340], 'conf': 0.824, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}, {'bbox': [11, 236, 62, 280], 'conf': 0.359, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}]
# [{'bbox': [0, 126, 239, 479], 'conf': 0.911, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 340], 'conf': 0.831, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [303, 319, 386, 419], 'conf': 0.311, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [11, 237, 58, 280], 'conf': 0.25, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 124, 240, 479], 'conf': 0.912, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [465, 164, 640, 340], 'conf': 0.821, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}, {'bbox': [289, 369, 321, 425], 'conf': 0.252, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}]
# [{'bbox': [0, 121, 238, 479], 'conf': 0.913, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [464, 164, 640, 341], 'conf': 0.83, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [307, 319, 386, 416], 'conf': 0.287, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 118, 234, 479], 'conf': 0.908, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.828, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [305, 319, 386, 418], 'conf': 0.283, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 116, 233, 479], 'conf': 0.913, 'class_no': 4, 'name': 'person', 'inf_time': 0.017}, {'bbox': [465, 164, 640, 340], 'conf': 0.837, 'class_no': 12, 'name': 'TV', 'inf_time': 0.017}]
# [{'bbox': [0, 114, 233, 479], 'conf': 0.909, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.827, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [303, 319, 386, 419], 'conf': 0.279, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [0, 112, 233, 479], 'conf': 0.913, 'class_no': 4, 'name': 'person', 'inf_time': 0.018}, {'bbox': [464, 164, 640, 340], 'conf': 0.826, 'class_no': 12, 'name': 'TV', 'inf_time': 0.018}, {'bbox': [298, 319, 385, 420], 'conf': 0.436, 'class_no': 7, 'name': 'chair', 'inf_time': 0.018}]
# [{'bbox': [0, 110, 233, 479], 'conf': 0.913, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.823, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}]
# [{'bbox': [0, 106, 235, 479], 'conf': 0.901, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [465, 164, 640, 340], 'conf': 0.821, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}]
# ...
# [{'bbox': [10, 266, 203, 479], 'conf': 0.521, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [155, 156, 638, 479], 'conf': 0.455, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [418, 351, 468, 381], 'conf': 0.308, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [93, 266, 202, 356], 'conf': 0.276, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [10, 266, 203, 478], 'conf': 0.573, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [156, 156, 638, 479], 'conf': 0.397, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.318, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [93, 266, 201, 356], 'conf': 0.26, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [10, 266, 203, 479], 'conf': 0.559, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [128, 155, 605, 479], 'conf': 0.417, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [418, 352, 468, 382], 'conf': 0.331, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}]
# [{'bbox': [10, 266, 201, 478], 'conf': 0.485, 'class_no': 7, 'name': 'chair', 'inf_time': 0.02}, {'bbox': [127, 155, 604, 479], 'conf': 0.382, 'class_no': 4, 'name': 'person', 'inf_time': 0.02}, {'bbox': [418, 352, 468, 382], 'conf': 0.301, 'class_no': 7, 'name': 'chair', 'inf_time': 0.02}, {'bbox': [93, 266, 199, 356], 'conf': 0.271, 'class_no': 7, 'name': 'chair', 'inf_time': 0.02}]
# [{'bbox': [10, 266, 199, 478], 'conf': 0.382, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [126, 155, 604, 479], 'conf': 0.362, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [93, 266, 198, 356], 'conf': 0.336, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.298, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [93, 266, 197, 357], 'conf': 0.446, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [124, 155, 545, 478], 'conf': 0.36, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.325, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [569, 239, 640, 412], 'conf': 0.272, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}]
# [{'bbox': [122, 155, 540, 479], 'conf': 0.396, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.392, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [93, 266, 196, 356], 'conf': 0.376, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 266, 197, 478], 'conf': 0.294, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [118, 155, 546, 479], 'conf': 0.391, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [10, 267, 196, 478], 'conf': 0.356, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.335, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [93, 266, 195, 356], 'conf': 0.334, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [101, 155, 529, 479], 'conf': 0.482, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [93, 267, 194, 356], 'conf': 0.386, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.332, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 267, 195, 478], 'conf': 0.273, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [102, 155, 525, 479], 'conf': 0.449, 'class_no': 4, 'name': 'person', 'inf_time': 0.017}, {'bbox': [94, 266, 193, 357], 'conf': 0.426, 'class_no': 7, 'name': 'chair', 'inf_time': 0.017}, {'bbox': [418, 352, 468, 382], 'conf': 0.394, 'class_no': 7, 'name': 'chair', 'inf_time': 0.017}, {'bbox': [10, 348, 146, 480], 'conf': 0.256, 'class_no': 7, 'name': 'chair', 'inf_time': 0.017}]
# [{'bbox': [95, 154, 530, 478], 'conf': 0.543, 'class_no': 4, 'name': 'person', 'inf_time': 0.017}, {'bbox': [94, 266, 192, 357], 'conf': 0.483, 'class_no': 7, 'name': 'chair', 'inf_time': 0.017}, {'bbox': [10, 348, 144, 480], 'conf': 0.31, 'class_no': 7, 'name': 'chair', 'inf_time': 0.017}, {'bbox': [418, 352, 468, 382], 'conf': 0.294, 'class_no': 7, 'name': 'chair', 'inf_time': 0.017}, {'bbox': [569, 241, 640, 410], 'conf': 0.255, 'class_no': 12, 'name': 'TV', 'inf_time': 0.017}]
# [{'bbox': [94, 154, 531, 478], 'conf': 0.554, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [93, 266, 192, 356], 'conf': 0.545, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.329, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 348, 143, 480], 'conf': 0.327, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [92, 154, 530, 478], 'conf': 0.543, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [94, 266, 191, 356], 'conf': 0.513, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.32, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 348, 142, 480], 'conf': 0.296, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [91, 154, 532, 478], 'conf': 0.547, 'class_no': 4, 'name': 'person', 'inf_time': 0.017}, {'bbox': [93, 266, 191, 356], 'conf': 0.505, 'class_no': 7, 'name': 'chair', 'inf_time': 0.017}, {'bbox': [10, 348, 141, 480], 'conf': 0.331, 'class_no': 7, 'name': 'chair', 'inf_time': 0.017}, {'bbox': [418, 352, 468, 381], 'conf': 0.308, 'class_no': 7, 'name': 'chair', 'inf_time': 0.017}]
# [{'bbox': [92, 154, 530, 478], 'conf': 0.538, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [93, 266, 191, 356], 'conf': 0.528, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 348, 140, 479], 'conf': 0.386, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 469, 382], 'conf': 0.334, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [91, 154, 530, 478], 'conf': 0.555, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [93, 266, 191, 356], 'conf': 0.514, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 348, 139, 479], 'conf': 0.354, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.325, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [91, 154, 531, 478], 'conf': 0.544, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [93, 266, 190, 356], 'conf': 0.537, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 347, 139, 479], 'conf': 0.391, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.301, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [89, 154, 529, 478], 'conf': 0.573, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [94, 266, 190, 356], 'conf': 0.539, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.404, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 348, 138, 479], 'conf': 0.357, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [406, 379, 493, 437], 'conf': 0.293, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [89, 154, 531, 479], 'conf': 0.55, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [93, 266, 190, 356], 'conf': 0.541, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 348, 138, 479], 'conf': 0.37, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.313, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [90, 154, 530, 478], 'conf': 0.564, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [94, 266, 190, 355], 'conf': 0.535, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [10, 348, 138, 480], 'conf': 0.354, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [418, 352, 468, 382], 'conf': 0.302, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}]
# [{'bbox': [88, 154, 529, 478], 'conf': 0.555, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [93, 266, 190, 355], 'conf': 0.516, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.378, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 348, 137, 480], 'conf': 0.308, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [89, 154, 528, 478], 'conf': 0.561, 'class_no': 4, 'name': 'person', 'inf_time': 0.014}, {'bbox': [94, 266, 189, 356], 'conf': 0.501, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}, {'bbox': [10, 348, 137, 479], 'conf': 0.314, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}, {'bbox': [418, 352, 469, 381], 'conf': 0.3, 'class_no': 7, 'name': 'chair', 'inf_time': 0.014}]
# [{'bbox': [88, 154, 530, 479], 'conf': 0.564, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [93, 266, 190, 355], 'conf': 0.528, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [10, 348, 137, 479], 'conf': 0.335, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [418, 352, 468, 381], 'conf': 0.298, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [569, 240, 640, 411], 'conf': 0.271, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}]
# [{'bbox': [89, 154, 528, 478], 'conf': 0.558, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [94, 266, 190, 355], 'conf': 0.486, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [418, 352, 468, 382], 'conf': 0.388, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [10, 348, 137, 479], 'conf': 0.337, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [569, 241, 640, 410], 'conf': 0.267, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}]
# [{'bbox': [87, 154, 529, 478], 'conf': 0.554, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [93, 267, 190, 356], 'conf': 0.492, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.395, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 348, 137, 479], 'conf': 0.337, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [88, 154, 531, 478], 'conf': 0.551, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [94, 266, 189, 355], 'conf': 0.516, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.34, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 348, 137, 479], 'conf': 0.294, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [88, 155, 530, 479], 'conf': 0.545, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [93, 266, 189, 355], 'conf': 0.543, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.355, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 348, 138, 479], 'conf': 0.341, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [567, 237, 640, 421], 'conf': 0.277, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}]
# [{'bbox': [88, 154, 532, 478], 'conf': 0.558, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [93, 266, 189, 356], 'conf': 0.52, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [418, 352, 468, 382], 'conf': 0.3, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [10, 348, 138, 479], 'conf': 0.272, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [569, 240, 640, 410], 'conf': 0.267, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}]
# [{'bbox': [89, 155, 529, 479], 'conf': 0.556, 'class_no': 4, 'name': 'person', 'inf_time': 0.017}, {'bbox': [94, 266, 190, 355], 'conf': 0.525, 'class_no': 7, 'name': 'chair', 'inf_time': 0.017}, {'bbox': [10, 348, 138, 480], 'conf': 0.38, 'class_no': 7, 'name': 'chair', 'inf_time': 0.017}, {'bbox': [418, 352, 468, 382], 'conf': 0.366, 'class_no': 7, 'name': 'chair', 'inf_time': 0.017}, {'bbox': [564, 239, 640, 422], 'conf': 0.267, 'class_no': 12, 'name': 'TV', 'inf_time': 0.017}]
# [{'bbox': [89, 155, 528, 478], 'conf': 0.548, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [93, 266, 191, 356], 'conf': 0.512, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.395, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 348, 138, 479], 'conf': 0.325, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [90, 155, 531, 479], 'conf': 0.541, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [94, 266, 190, 355], 'conf': 0.499, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [568, 238, 640, 415], 'conf': 0.348, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [10, 348, 138, 479], 'conf': 0.309, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 469, 382], 'conf': 0.295, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [93, 266, 190, 356], 'conf': 0.545, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [89, 155, 531, 479], 'conf': 0.542, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [10, 348, 138, 480], 'conf': 0.386, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.299, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [94, 266, 190, 356], 'conf': 0.548, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [89, 155, 531, 479], 'conf': 0.542, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [10, 348, 138, 480], 'conf': 0.367, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [418, 352, 468, 382], 'conf': 0.311, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}]
# [{'bbox': [87, 155, 531, 478], 'conf': 0.566, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [94, 266, 191, 356], 'conf': 0.517, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.369, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 348, 139, 479], 'conf': 0.349, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [90, 155, 531, 479], 'conf': 0.536, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [93, 266, 191, 356], 'conf': 0.468, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.315, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [10, 347, 140, 479], 'conf': 0.311, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [94, 266, 191, 356], 'conf': 0.568, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [91, 155, 531, 478], 'conf': 0.549, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [10, 347, 140, 479], 'conf': 0.369, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.345, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [567, 239, 640, 415], 'conf': 0.268, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}]
# [{'bbox': [93, 266, 192, 356], 'conf': 0.519, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [91, 155, 532, 478], 'conf': 0.517, 'class_no': 4, 'name': 'person', 'inf_time': 0.015}, {'bbox': [10, 347, 140, 480], 'conf': 0.339, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}, {'bbox': [567, 238, 640, 421], 'conf': 0.301, 'class_no': 12, 'name': 'TV', 'inf_time': 0.015}, {'bbox': [418, 352, 468, 382], 'conf': 0.285, 'class_no': 7, 'name': 'chair', 'inf_time': 0.015}]
# [{'bbox': [91, 156, 530, 479], 'conf': 0.534, 'class_no': 4, 'name': 'person', 'inf_time': 0.016}, {'bbox': [94, 266, 192, 356], 'conf': 0.528, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [10, 348, 141, 480], 'conf': 0.363, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [418, 352, 468, 381], 'conf': 0.316, 'class_no': 7, 'name': 'chair', 'inf_time': 0.016}, {'bbox': [567, 238, 640, 421], 'conf': 0.256, 'class_no': 12, 'name': 'TV', 'inf_time': 0.016}]
